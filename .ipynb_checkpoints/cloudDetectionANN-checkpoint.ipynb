# %% [markdown]
# ## Neural Network Cloud Detection
# 1. Data Peprocessing for Neural Network

# %%
import numpy as np
# Grab Dataset
data = np.genfromtxt('data.csv', delimiter=',')

# %%
# Split data into y (label) and x (features)
y = data[:,0]
x = data[:,1:22]
x = np.nan_to_num(x, nan=0.0)

# %%
# Any multi-layer cloud labels set to 1, turn into classification [cloud, no cloud]=[1,0]
y = np.where(y >= 1, 1, y)
print(y[0])
# Out:
# 0.0

# %%
from sklearn.model_selection import train_test_split
# Split data into Train/Test/Validation 70/20/10
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.125, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
# Scale data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_val = scaler.transform(X_val)

# %% [markdown]
# 2. Build Neural Network Model

# %%
import tensorflow.keras as ks

model = ks.Sequential([
    ks.layers.Dense(32, activation='relu', input_shape=(x.shape[1],)),
    ks.layers.Dense(16, activation='relu'),
    ks.layers.Dense(8, activation='relu'),
    ks.layers.Dense(8, activation='relu'),
    ks.layers.Dense(4, activation='relu'),
    ks.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# 3. Train Model

# %%
import matplotlib.pyplot as plt

# Train model
history = model.fit(X_train, y_train, epochs=40, batch_size=32, validation_data=(X_val, y_val))

# Plot training and validation accuracy over epochs
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.show()

# Evaluate model on test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# Epoch 1/40
# 3821/3821 [==============================] - 5s 1ms/step - loss: 0.3562 - accuracy: 0.8307 - val_loss: 0.3193 - val_accuracy: 0.8477
# Epoch 2/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.3049 - accuracy: 0.8550 - val_loss: 0.2989 - val_accuracy: 0.8574
# Epoch 3/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2956 - accuracy: 0.8586 - val_loss: 0.3071 - val_accuracy: 0.8563
# Epoch 4/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2886 - accuracy: 0.8632 - val_loss: 0.2804 - val_accuracy: 0.8638
# Epoch 5/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2854 - accuracy: 0.8645 - val_loss: 0.2787 - val_accuracy: 0.8660
# Epoch 6/40
# 3821/3821 [==============================] - 5s 1ms/step - loss: 0.2810 - accuracy: 0.8654 - val_loss: 0.2766 - val_accuracy: 0.8680
# Epoch 7/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2767 - accuracy: 0.8685 - val_loss: 0.2724 - val_accuracy: 0.8717
# Epoch 8/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2740 - accuracy: 0.8694 - val_loss: 0.2713 - val_accuracy: 0.8710
# Epoch 9/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2712 - accuracy: 0.8711 - val_loss: 0.2639 - val_accuracy: 0.8752
# Epoch 10/40
# 3821/3821 [==============================] - 5s 1ms/step - loss: 0.2692 - accuracy: 0.8703 - val_loss: 0.2787 - val_accuracy: 0.8671
# Epoch 11/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2671 - accuracy: 0.8728 - val_loss: 0.2612 - val_accuracy: 0.8727
# Epoch 12/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2645 - accuracy: 0.8725 - val_loss: 0.2617 - val_accuracy: 0.8727
# Epoch 13/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2634 - accuracy: 0.8743 - val_loss: 0.2522 - val_accuracy: 0.8804
# Epoch 14/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2608 - accuracy: 0.8753 - val_loss: 0.2576 - val_accuracy: 0.8771
# Epoch 15/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2598 - accuracy: 0.8747 - val_loss: 0.2545 - val_accuracy: 0.8768
# Epoch 16/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2588 - accuracy: 0.8759 - val_loss: 0.2492 - val_accuracy: 0.8812
# Epoch 17/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2567 - accuracy: 0.8771 - val_loss: 0.2524 - val_accuracy: 0.8769
# Epoch 18/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2554 - accuracy: 0.8777 - val_loss: 0.2690 - val_accuracy: 0.8689
# Epoch 19/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2533 - accuracy: 0.8777 - val_loss: 0.2433 - val_accuracy: 0.8830
# Epoch 20/40
# 3821/3821 [==============================] - 5s 1ms/step - loss: 0.2524 - accuracy: 0.8796 - val_loss: 0.2448 - val_accuracy: 0.8808
# Epoch 21/40
# 3821/3821 [==============================] - 5s 1ms/step - loss: 0.2508 - accuracy: 0.8793 - val_loss: 0.2365 - val_accuracy: 0.8831
# Epoch 22/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2505 - accuracy: 0.8797 - val_loss: 0.2421 - val_accuracy: 0.8811
# Epoch 23/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2484 - accuracy: 0.8805 - val_loss: 0.2467 - val_accuracy: 0.8836
# Epoch 24/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2478 - accuracy: 0.8798 - val_loss: 0.2535 - val_accuracy: 0.8803
# Epoch 25/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2462 - accuracy: 0.8813 - val_loss: 0.2392 - val_accuracy: 0.8840
# Epoch 26/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2465 - accuracy: 0.8808 - val_loss: 0.2325 - val_accuracy: 0.8854
# Epoch 27/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2447 - accuracy: 0.8819 - val_loss: 0.2350 - val_accuracy: 0.8832
# Epoch 28/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2434 - accuracy: 0.8815 - val_loss: 0.2347 - val_accuracy: 0.8830
# Epoch 29/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2424 - accuracy: 0.8822 - val_loss: 0.2282 - val_accuracy: 0.8847
# Epoch 30/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2430 - accuracy: 0.8828 - val_loss: 0.2273 - val_accuracy: 0.8866
# Epoch 31/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2387 - accuracy: 0.8835 - val_loss: 0.2237 - val_accuracy: 0.8863
# Epoch 32/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2392 - accuracy: 0.8837 - val_loss: 0.2251 - val_accuracy: 0.8826
# Epoch 33/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2379 - accuracy: 0.8829 - val_loss: 0.2474 - val_accuracy: 0.8737
# Epoch 34/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2362 - accuracy: 0.8838 - val_loss: 0.2243 - val_accuracy: 0.8866
# Epoch 35/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2367 - accuracy: 0.8833 - val_loss: 0.2258 - val_accuracy: 0.8838
# Epoch 36/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2333 - accuracy: 0.8836 - val_loss: 0.2227 - val_accuracy: 0.8812
# Epoch 37/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2304 - accuracy: 0.8836 - val_loss: 0.2176 - val_accuracy: 0.8793
# Epoch 38/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2292 - accuracy: 0.8827 - val_loss: 0.1998 - val_accuracy: 0.8868
# Epoch 39/40
# 3821/3821 [==============================] - 4s 1ms/step - loss: 0.2248 - accuracy: 0.8815 - val_loss: 0.2057 - val_accuracy: 0.8718
# Epoch 40/40
# 3821/3821 [==============================] - 5s 1ms/step - loss: 0.2184 - accuracy: 0.8822 - val_loss: 0.1777 - val_accuracy: 0.8799
# 1092/1092 [==============================] - 1s 927us/step - loss: 0.2382 - accuracy: 0.8795
# Test Accuracy: 0.8794949650764465
